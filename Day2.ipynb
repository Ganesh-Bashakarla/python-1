# %%
name = "Ramesh"
roll_no = 101
cgpa = 9.0
print(name,roll_no,cgpa)
print(name)
print(roll_no)
print(cgpa)
# Out:
# Ramesh 101 9.0
# Ramesh
# 101
# 9.0

# %%
name = "ramesh"
name = "suresh"
cgpa = 9.0
cgpa = 8.5
print(name)
print(cgpa)
# Out:
# suresh
# 8.5

# %%
#case-2(Using operators)
x = 12
y = 45
print(x,y)
z = (x+y)
x = z - x
y = z - y
print(x,y)
# Out:
# 12 45
# 45 12

# %%
#case-3(Without using temporary variable)
x = 18
y = 45
print(x,y)
x,y = y,x
print(x,y)
# Out:
# 18 45
# 45 18

# %%
cgpa = 8.5
cgpa = 9.5
print(cgpa)
del(cgpa)
Print(cgpa)
# Out:
# 9.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 cgpa = 8.5
#       2 cgpa = 9.5
#       3 print(cgpa)
#       4 del(cgpa)
# ----> 5 Print(cgpa)
#
# NameError: name 'Print' is not defined
