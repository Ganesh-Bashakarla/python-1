# %%
print("Hello World")
# Out:
# Hello World

# %%
#case-1
name = "Ganesh"
print(name)
#case-2
age = "22"
print(age)
#case3-
my_name = "Nithin"
print(my_name)
#case4-
num1 = "abc"
print(num1)
# Out:
# Ganesh
# 22
# Nithin
# abc

# %%
#case1-
College = "abc"
print(college) 
#case2-
1num = 10
print(1num) 
#case3-
# %name = "Ganesh"
print(%name) 
#case4-
my name = "Ganesh"
print(my name)
# Out:
#   Cell In[6], line 5
#     1num = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
name = "ramesh"
roll_no = 101
print(name,roll_no)
# Out:
# ramesh 101

# %%
#case1-(single line comment)
#student = "suresh" #use hash(#) symbol at starting

#case2-(multi line comment)
# name = "ramesh"# select the text and press ctrl + /(Forward slash)
# roll_no = 101
# print(name,roll_no)
