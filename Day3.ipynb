# %%
age = 22
cgpa = 8.9
x = 3+5j
print(type(age))
print(type(cgpa))
print(type(x))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# #### Sequence Data Type

# %%
lst=[1,2,3,4,5]
print(lst)
lst[0]=10
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [10, 2, 3, 4, 5]

# %%
#tuple
t =(1,2,3,4,5)
print(t)
t(2)=90
print(t)
# Out:
#   Cell In[4], line 4
#     t(2)=90
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
lst_1 = [1, 2, 3, 4, 5]
lst_2 = [10, 20, 20, "Students", "A"]

print(lst_1)
print(lst_2)

lst_1[0] = 10
print(lst_1)
# Out:
# [1, 2, 3, 4, 5]
# [10, 20, 20, 'Students', 'A']
# [10, 2, 3, 4, 5]

# %%
#strings
s = "codegang"
print(s)
print(s[0])
# Out:
# codegang
# c

# %%
#Mapping
#dictionary
student = {
    "name": "Ganesh",
    "age": 23,
    "branch": "CSE"
}

print(student)

# dic
student = {
    "name": "Ganesh",
    "age": 23,
    "marks": 85
}

print(student)
# Out:
# {'name': 'Ganesh', 'age': 23, 'branch': 'CSE'}
# {'name': 'Ganesh', 'age': 23, 'marks': 85}

# %%
#set
s1={1,2,3}
s2={2,1,4,3,5,3,6}
print(s2)
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3}

# %% [markdown]
# # Type Casting

# %%
#Implicit Type Casting
a = 10
b = 5.5

c = a + b

print(c)
print(type(c))
# Out:
# 15.5
# <class 'float'>

# %%
#Explicit Type Casting
a = "10"

b = int(a)

print(b)
print(type(b))
# Out:
# 10
# <class 'int'>
