# %% [markdown]
# # Operators in Python

# %%
a=10
b=5
print(a+b)
# Out:
# 15

# %% [markdown]
# # Arithmetic Operators

# %%
a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# # Comparison Operators

# %%
a = 10
b = 5

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# # Logical Operators

# %%
#There are three:
#and
#or
#not

#and

age = 23

print(age > 18 and age < 30)
# Out:
# True

# %%
#or
age = 23

print(age < 18 or age > 20)
# Out:
# True

# %%
#not
x = True

print(not x)
# Out:
# False

# %% [markdown]
# # Assignment Operators

# %%
#Assignment operators are used to assign or update values.
#Normal assignment
x = 10

# %%
#Other assignment operators
x = 10

x += 5
print(x)
# Out:
# 15

# %%
x = 10

x += 5
print("After += 5:", x)

x -= 2
print("After -= 2:", x)

x *= 3
print("After *= 3:", x)

x /= 2
print("After /= 2:", x)

x //= 2
print("After //= 2:", x)

x %= 2
print("After %= 2:", x)

x **= 2
print("After **= 2:", x)
# Out:
# After += 5: 15
# After -= 2: 13
# After *= 3: 39
# After /= 2: 19.5
# After //= 2: 9.0
# After %= 2: 1.0
# After **= 2: 1.0

# %% [markdown]
# # Membership Operators

# %%
#Membership operators check whether a value exists inside a sequence such as a list or string.
#There are two:
#in
#not in

fruits = ["apple", "banana", "mango"]

print("apple" in fruits)
print("orange" in fruits)

#Example with string:
name = "Ganesh"
print("G" in name)
print("p" in name)
# Out:
# True
# False
# True
# False

# %% [markdown]
# # Identity Operators

# %%
#Identity operators check whether two variables refer to the same object.
#They are:
#is
#is not
a = [1, 2, 3]
b = a

print(a is b)
# Out:
# True

# %%
#For normal value comparison, use ==
a = [1, 2, 3]
b = [1, 2, 3]
print(a == b)
print(a is b)
# Out:
# True
# False

# %% [markdown]
# # Bitwise Operators

# %%
#Bitwise operators work with numbers at the binary/bit level.
# Common operators:
# &   AND
# |   OR
# ^   XOR
# ~   NOT
# <<  Left shift
# >>  Right shift

a = 5
b = 3

print(a & b)
print(a | b)
print(a ^ b)
# Out:
# 1
# 7
# 6
